# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\oswal\Documents\Documentos\Ciencias de Datos\5° Semestre\Herramientas para grandes volumenes de datos\python\datos_abiertos_covid19\220120COVID19MEXICO.csv',
                 header=0,
                 low_memory=True,
                 parse_dates=['FECHA_ACTUALIZACION', 'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF'])
# Out:
# C:\Users\oswal\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df['SEXO'] = df['SEXO'].replace({1: 'MUJER',
                                 2: 'HOMBRE',
                                 3: 'NO ESPECIFICADO'})

# %% [markdown]
# ## POSITIVOS

# %%
#DATOS
#SEPARAMOS, UNIMOS Y AGRUPAMOS
df1 = df[(df['CLASIFICACION_FINAL'] == 1)]
df2 = df[(df['CLASIFICACION_FINAL'] == 2)]
df3 = df[(df['CLASIFICACION_FINAL'] == 3)]
positivos = pd.concat([df1, df2, df3])
plot = positivos.groupby(["FECHA_SINTOMAS", 'SEXO']).count()

#GRAFICO
sns.relplot(data=plot, x='FECHA_SINTOMAS', y='PAIS_NACIONALIDAD', hue='SEXO')
ax = plt.gca()
ax.axes.xaxis.set_visible(True)
ax.axes.yaxis.set_visible(True)
plt.xticks(rotation=25, ha='right')
# Out:
# (array([18353., 18444., 18536., 18628., 18718., 18809., 18901., 18993.]),
#  [Text(18353.0, 0, '2020-04'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18536.0, 0, '2020-10'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18718.0, 0, '2021-04'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18901.0, 0, '2021-10'),
#   Text(18993.0, 0, '2022-01')])

# %%
plot.tail(19)
# Out:
#                        FECHA_ACTUALIZACION  ID_REGISTRO  ORIGEN  SECTOR  \
# FECHA_SINTOMAS SEXO
# 2022-01-11     HOMBRE                15287        15287   15287   15287
#                MUJER                 19904        19904   19904   19904
# 2022-01-12     HOMBRE                13002        13002   13002   13002
#                MUJER                 16545        16545   16545   16545
# 2022-01-13     HOMBRE                10535        10535   10535   10535
#                MUJER                 13386        13386   13386   13386
# 2022-01-14     HOMBRE                 9729         9729    9729    9729
#                MUJER                 12693        12693   12693   12693
# 2022-01-15     HOMBRE                 8294         8294    8294    8294
#                MUJER                 11074        11074   11074   11074
# 2022-01-16     HOMBRE                 6278         6278    6278    6278
#                MUJER                  7917         7917    7917    7917
# ...

# %% [markdown]
# ## NEGATIVOS

# %%
df1 = df[(df['CLASIFICACION_FINAL'] ==  7)]
plot = df1.groupby(["FECHA_SINTOMAS", 'SEXO']).count()

#GRAFICO
sns.relplot(data=plot, x= 'FECHA_SINTOMAS', y='PAIS_NACIONALIDAD', hue='SEXO')
ax = plt.gca()
ax.axes.xaxis.set_visible(True)
ax.axes.yaxis.set_visible(True)
plt.xticks(rotation=25, ha='right')
# Out:
# (array([18262., 18353., 18444., 18536., 18628., 18718., 18809., 18901.,
#         18993.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18353.0, 0, '2020-04'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18536.0, 0, '2020-10'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18718.0, 0, '2021-04'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18901.0, 0, '2021-10'),
#   Text(18993.0, 0, '2022-01')])

# %% [markdown]
# ## INVALIDOS Y NO REALIZADOS

# %%
df1 = df[(df['CLASIFICACION_FINAL'] ==  4)]
df2 = df[(df['CLASIFICACION_FINAL'] ==  5)]
invalidos = pd.concat([df1, df2])
plot = invalidos.groupby(["FECHA_SINTOMAS", 'SEXO']).count()

#GRAFICO
sns.relplot(data=plot, x= 'FECHA_SINTOMAS', y='PAIS_NACIONALIDAD', hue='SEXO')
ax = plt.gca()
ax.axes.xaxis.set_visible(True)
ax.axes.yaxis.set_visible(True)
plt.xticks(rotation=25, ha='right')
# Out:
# (array([18262., 18353., 18444., 18536., 18628., 18718., 18809., 18901.,
#         18993.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18353.0, 0, '2020-04'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18536.0, 0, '2020-10'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18718.0, 0, '2021-04'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18901.0, 0, '2021-10'),
#   Text(18993.0, 0, '2022-01')])

# %% [markdown]
# ## SOSPECHOSOS

# %%
df1 = df[(df['CLASIFICACION_FINAL'] ==  6)]
plot = df1.groupby(["FECHA_SINTOMAS", 'SEXO']).count()

#GRAFICO
sns.relplot(data=plot, x= 'FECHA_SINTOMAS', y='PAIS_NACIONALIDAD', hue='SEXO')
ax = plt.gca()
ax.axes.xaxis.set_visible(True)
ax.axes.yaxis.set_visible(True)
plt.xticks(rotation=25, ha='right')
# Out:
# (array([18262., 18353., 18444., 18536., 18628., 18718., 18809., 18901.,
#         18993.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18353.0, 0, '2020-04'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18536.0, 0, '2020-10'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18718.0, 0, '2021-04'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18901.0, 0, '2021-10'),
#   Text(18993.0, 0, '2022-01')])

# %% [markdown]
# ## HUE = CLASIFICACION FINAL

# %%
df['CLASIFICACION_FINAL']=df['CLASIFICACION_FINAL'].replace({1: 'CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA',
                                                             2: 'CASO DE COVID-19 CONFIRMADO POR COMITÉ DE DICTAMINACIÓN',
                                                             3: 'CASO DE SARS-COV-2 CONFIRMADO',
                                                             4: 'INVÁLIDO POR LABORATORIO',
                                                             5: 'NO REALIZADO POR LABORATORIO',
                                                             6: 'CASO SOSPECHOSO',
                                                             7: 'NEGATIVO A SARS-COV-2'})

# %%
#DATOS
plot = df.groupby(["FECHA_SINTOMAS", 'CLASIFICACION_FINAL']).count()

#GRAFICO
sns.relplot(data=plot, x='FECHA_SINTOMAS', y='PAIS_NACIONALIDAD', hue='CLASIFICACION_FINAL')
ax = plt.gca()
ax.axes.xaxis.set_visible(True)
ax.axes.yaxis.set_visible(True)
plt.xticks(rotation=25, ha='right')
# Out:
# (array([18262., 18353., 18444., 18536., 18628., 18718., 18809., 18901.,
#         18993.]),
#  [Text(18262.0, 0, '2020-01'),
#   Text(18353.0, 0, '2020-04'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18536.0, 0, '2020-10'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18718.0, 0, '2021-04'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18901.0, 0, '2021-10'),
#   Text(18993.0, 0, '2022-01')])
